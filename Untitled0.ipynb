# %% [markdown]
# <a href="https://colab.research.google.com/github/annasandrade/Python-Mundo-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto = input('Digite algo: ')
print('É alfabético?', texto.isalpha())
print('É numero?', texto.isnumeric())
print("Só tem espaços?", texto.isspace())
print("É alfanumérico?", texto.isalnum())
print("Está em maiúsculas?", texto.isupper())
print("Está em minúsculas?", texto.islower())
print("Está em formato título?", texto.istitle())
# Out:
# Digite algo: Jesus
# É alfabético? True
# É numero? False
# Só tem espaços? False
# É alfanumérico? True
# Está em maiúsculas? False
# Está em minúsculas? False
# Está em formato título? True
